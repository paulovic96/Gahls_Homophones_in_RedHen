# %%
import os
import preprocessing
import pandas as pd
import numpy as np
import importlib
from english_contractions import ENGLISH_CONTRACTIONS
import merging_dataframes
import word_pronunciation_predictibility
import celex_files

# %%
celex_dict_file = "/mnt/shared/corpora/Celex/english/epw/epw.cd"
filename = "/mnt/Restricted/Corpora/RedHen/2016_all_words_no_audio.pickle"
hom_filename = "/mnt/Restricted/Corpora/RedHen/homophone_analysis_scripts/hom.csv"
berndt_character_coding_file = "/mnt/Restricted/Corpora/RedHen/homophone_analysis_scripts/phonetic_character_code_berndt1987.csv"
berndt_conditional_probs_file = "/mnt/Restricted/Corpora/RedHen/homophone_analysis_scripts/Conditional_Probabilities_for_Grapheme-to-Phoneme_Correspondences_Berndt1987.csv"

# %%
df = preprocessing.read_dataframe(filename, remove_pauses=True, remove_errors=True, preprocessing=True, drop_error_columns=False)
# Out:
# read dataframe from /mnt/Restricted/Corpora/RedHen/2016_all_words_no_audio.pickle
# Preprocessing: extract pause information...
# Remove pauses from data!
# Preprocessing: apply word preprocessing...
# Preprocessing: calculate word duration...
# Preprocessing: calculate word frequency...
# Preprocessing: extract context information...
# Preprocessing: calculate length in letter...
# Preprocessing: calculate contextual predictability...
# (18864660, 25) RangeIndex(start=0, stop=18864660, step=1)

# %% [markdown]
# # Homographs

# %% [markdown]
# ### Problematic cases:
# - excuse (N) is pronounced with a /s/ and excuse (V) is pronounces with a /z/.
# - practice : is listed only as Noun in celex. This is because the verb is spelled as "practise" in British English (celex) and "practice" in American English.

# %%
homograph_pairs = ["act", "answer","attack", "break", "call", "calls", "care", "cause", "change", "check", "control",      
                   "cook", "cost", "cut", "deal", "dress", "drive", "end", "face", "fall", "fight", "fire",
                   "focus", "help", "hope", "limit", "look", "love", "matter", "mind", "name","need", "needs","notice",
                   "offer", "order", "pass", "pay", "plan", "play", "raise","rent", "respect","ride","run",
                   "set", "show", "shows", "sign", "sleep", "sound", "stand", "struggle", "study", "support", "talk", "touch", 
                   "turn", "vote", "waste", "work"]

# %%
gahls_homophones = pd.read_csv(hom_filename, index_col="Unnamed: 0")

# %% [markdown]
# ## Homographs In Data

# %%
df
# Out:
#                                                 source_file      word  \
# 0                    2016-01-01_0100_US_KNBC_Channel_4_News   klemack
# 1                    2016-01-01_0100_US_KNBC_Channel_4_News  happened
# 2                    2016-01-01_0100_US_KNBC_Channel_4_News        to
# 3                    2016-01-01_0100_US_KNBC_Channel_4_News        be
# 4                    2016-01-01_0100_US_KNBC_Channel_4_News     there
# ...                                                     ...       ...
# 18864655  2016-12-31_2300_US_CNN_CNN_Newsroom_With_Poppy...    follow
# 18864656  2016-12-31_2300_US_CNN_CNN_Newsroom_With_Poppy...       the
# 18864657  2016-12-31_2300_US_CNN_CNN_Newsroom_With_Poppy...     story
# 18864658  2016-12-31_2300_US_CNN_CNN_Newsroom_With_Poppy...       all
# 18864659  2016-12-31_2300_US_CNN_CNN_Newsroom_With_Poppy...   evening
#
#             start      end  duration       label_type mp4_error aac_error  \
# 0            0.27     0.69      0.42  high-confidence  no-error  no-error
# 1            0.92     1.34      0.42  high-confidence  no-error  no-error
# 2            1.34     1.46      0.12  high-confidence  no-error  no-error
# 3            1.47     1.73      0.26  high-confidence  no-error  no-error
# 4            1.73     1.97      0.24  high-confidence  no-error  no-error
# ...           ...      ...       ...              ...       ...       ...
# 18864655  3458.11  3458.37      0.26  high-confidence  no-error  no-error
# 18864656  3458.38  3458.53      0.15  high-confidence  no-error  no-error
# 18864657  3458.53  3459.05      0.52  high-confidence  no-error  no-error
# 18864658  3459.10  3459.39      0.29  high-confidence  no-error  no-error
# 18864659  3459.42  3459.86      0.44  high-confidence  no-error  no-error
#
#          aac2wav_error eafgz_error  ... prev_word_frequency  next_word  \
# 0             no-error    no-error  ...                 NaN   happened
# 1             no-error    no-error  ...                33.0         to
# 2             no-error    no-error  ...              8596.0         be
# 3             no-error    no-error  ...            539420.0      there
# 4             no-error    no-error  ...            102918.0         on
# ...                ...         ...  ...                 ...        ...
# 18864655      no-error    no-error  ...            128106.0        the
# 18864656      no-error    no-error  ...              1791.0      story
# 18864657      no-error    no-error  ...            932396.0        all
# 18864658      no-error    no-error  ...              7440.0    evening
# 18864659      no-error    no-error  ...             62248.0        NaN
#
#           next_word_frequency  length_in_letter  prev_word_string  \
# 0                      8596.0                 7               NaN
# 1                    539420.0                 8  klemack-happened
# 2                    102918.0                 2       happened-to
# 3                     59861.0                 2             to-be
# 4                    151861.0                 5          be-there
# ...                       ...               ...               ...
# 18864655             932396.0                 6         we-follow
# 18864656               7440.0                 3        follow-the
# 18864657              62248.0                 5         the-story
# 18864658               4470.0                 3         story-all
# 18864659                  NaN                 7       all-evening
#
#           next_word_string prev_word_string_frequency  \
# 0         klemack-happened                        NaN
# 1              happened-to                        1.0
# 2                    to-be                      910.0
# 3                 be-there                    37236.0
# 4                 there-on                      686.0
# ...                    ...                        ...
# 18864655        follow-the                       69.0
# 18864656         the-story                      389.0
# 18864657         story-all                     1904.0
# 18864658       all-evening                       29.0
# 18864659               NaN                       14.0
#
#           next_word_string_frequency  cond_pred_prev cond_pred_next
# 0                                1.0             NaN       0.000116
# 1                              910.0        0.030303       0.001687
# 2                            37236.0        0.105863       0.361803
# 3                              686.0        0.069030       0.011460
# 4                              478.0        0.006666       0.003148
# ...                              ...             ...            ...
# 18864655                       389.0        0.000539       0.000417
# 18864656                      1904.0        0.217197       0.255914
# 18864657                        29.0        0.002042       0.000466
# 18864658                        14.0        0.003898       0.003132
# 18864659                         NaN        0.000225            NaN
#
# [18864660 rows x 25 columns]

# %%
homographs_in_data = df[df.word.isin(homograph_pairs)]

# %%
print("%d out of %d homographs found in Data:" % (len(np.unique(homographs_in_data.word)), len(homograph_pairs)))
# Out:
# 61 out of 61 homographs found in Data:

# %% [markdown]
# # Celex information

# %%
celex_dict = word_pronunciation_predictibility.get_english_phonology_from_celex(celex_dict_file)

# %%
words, counts = np.unique(celex_dict[celex_dict.word.isin(homograph_pairs)].word, return_counts = True)
print(words[np.where(counts==2)])
# Out:
# []

# %%
clex_info = celex_dict[celex_dict.word.isin(homograph_pairs)]#.groupby('word').first().reset_index()

# %%
clex_info
# Out:
#          word     disc          clx disc_no_bound clx_no_bound
# 669       act     '{kt        [&kt]           {kt          &kt
# 2702   answer  '#n-s@R  [A:n][s@r*]         #ns@R      A:ns@r*
# 4201   attack   @-'t{k     [@][t&k]          @t{k         @t&k
# 9582    break    'br1k      [breIk]          br1k        breIk
# 11570    call     'k$l       [kO:l]           k$l         kO:l
# ...       ...      ...          ...           ...          ...
# 92154   touch     'tVJ       [tVtS]           tVJ         tVtS
# 93820    turn     't3n       [t3:n]           t3n         t3:n
# 96903    vote     'v5t       [v@Ut]           v5t         v@Ut
# 97626   waste    'w1st      [weIst]          w1st        weIst
# 99726    work     'w3k       [w3:k]           w3k         w3:k
#
# [61 rows x 5 columns]

# %%
homographs_in_data_celex_merged = homographs_in_data.merge(clex_info,
                    how = "left",
                    on = "word")

# %%
print(len(homographs_in_data_celex_merged))
print(len(homographs_in_data))
# Out:
# 294818
# 294818

# %%
#homographs_in_data_celex_merged.to_csv("2016_all_words_no_audio_homographs.csv")

# %%
homographs_in_data_celex_merged = pd.read_csv("2016_all_words_no_audio_homographs.csv", index_col = "Unnamed: 0")

# %%
homographs_in_data_celex_merged
# Out:
#                                               source_file    word  \
# 0                  2016-01-01_0100_US_KNBC_Channel_4_News    fire
# 1                  2016-01-01_0100_US_KNBC_Channel_4_News    show
# 2                  2016-01-01_0100_US_KNBC_Channel_4_News    fire
# 3                  2016-01-01_0100_US_KNBC_Channel_4_News    fire
# 4                  2016-01-01_0100_US_KNBC_Channel_4_News    fire
# ...                                                   ...     ...
# 294813  2016-12-31_2300_US_CNN_CNN_Newsroom_With_Poppy...     end
# 294814  2016-12-31_2300_US_CNN_CNN_Newsroom_With_Poppy...   check
# 294815  2016-12-31_2300_US_CNN_CNN_Newsroom_With_Poppy...  attack
# 294816  2016-12-31_2300_US_CNN_CNN_Newsroom_With_Poppy...     end
# 294817  2016-12-31_2300_US_CNN_CNN_Newsroom_With_Poppy...     end
#
#               start          end  duration       label_type mp4_error  \
# 0         21.750000    22.110000      0.36  high-confidence  no-error
# 1         43.280000    43.450000      0.17  high-confidence  no-error
# 2         46.349999    46.879999      0.53  high-confidence  no-error
# 3         48.070000    48.290000      0.22  high-confidence  no-error
# 4         68.990000    69.380000      0.39  high-confidence  no-error
# ...             ...          ...       ...              ...       ...
# 294813  3135.330000  3135.820000      0.49  high-confidence  no-error
# 294814  3149.670000  3149.980000      0.31  high-confidence  no-error
# 294815  3252.360000  3252.980000      0.62  high-confidence  no-error
# 294816  3356.230000  3356.390000      0.16  high-confidence  no-error
# 294817  3446.380000  3446.730000      0.35  high-confidence  no-error
#
#        aac_error aac2wav_error eafgz_error  ... prev_word_string  \
# 0       no-error      no-error    no-error  ...        this-fire
# 1       no-error      no-error    no-error  ...   fireworks-show
# 2       no-error      no-error    no-error  ...         the-fire
# 3       no-error      no-error    no-error  ...         the-fire
# 4       no-error      no-error    no-error  ...       hotel-fire
# ...          ...           ...         ...  ...              ...
# 294813  no-error      no-error    no-error  ...         high-end
# 294814  no-error      no-error    no-error  ...       also-check
# 294815  no-error      no-error    no-error  ...      this-attack
# 294816  no-error      no-error    no-error  ...         high-end
# 294817  no-error      no-error    no-error  ...         high-end
#
#         next_word_string  prev_word_string_frequency  \
# 0             fire-broke                       229.0
# 1                show-to                        26.0
# 2               fire-the                      1104.0
# 3           fire-started                      1104.0
# 4            fire-nearby                         2.0
# ...                  ...                         ...
# 294813     end-nightclub                       153.0
# 294814         check-out                        11.0
# 294815       attack-this                       458.0
# 294816     end-nightclub                       153.0
# 294817     end-nightclub                       153.0
#
#         next_word_string_frequency cond_pred_prev  cond_pred_next    disc  \
# 0                             66.0       0.001380        0.046381  'f2-@R
# 1                             70.0       0.047016        0.000130     'S5
# 2                            200.0       0.001184        0.000215  'f2-@R
# 3                             69.0       0.001184        0.011880  'f2-@R
# 4                              1.0       0.001541        0.001164  'f2-@R
# ...                            ...            ...             ...     ...
# 294813                         3.0       0.014494        0.005587    'End
# 294814                       504.0       0.000428        0.008911    'JEk
# 294815                        84.0       0.002761        0.000506  @-'t{k
# 294816                         3.0       0.014494        0.005587    'End
# 294817                         3.0       0.014494        0.005587    'End
#
#                clx  disc_no_bound clx_no_bound
# 0       [faI][@r*]           f2@R       faI@r*
# 1            [S@U]             S5          S@U
# 2       [faI][@r*]           f2@R       faI@r*
# 3       [faI][@r*]           f2@R       faI@r*
# 4       [faI][@r*]           f2@R       faI@r*
# ...            ...            ...          ...
# 294813       [End]            End          End
# 294814      [tSEk]            JEk         tSEk
# 294815    [@][t&k]           @t{k         @t&k
# 294816       [End]            End          End
# 294817       [End]            End          End
#
# [294818 rows x 29 columns]

# %% [markdown]
# # Load Additional Information
# - eaf files
# - seg files
# - gentle files

# %% [markdown]
# ## EAF Files
# - information about present gestures

# %%
eaf_data = pd.read_csv("2016_all_words_no_audio_eaf_gesture.csv",index_col = "Unnamed: 0")
# Out:
# /home/paul/anaconda3/envs/bon18/lib/python3.8/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %% [markdown]
# ## SEG files
# - information about Part Of Speech
# - information about Phrase final marker

# %%
seg_data = pd.read_csv("2016_all_words_no_audio_seg_data.csv",index_col = "Unnamed: 0")

# %% [markdown]
# ## GENTLE files
# - information about Phrase final marker

# %%
gentle_data = pd.read_csv("2016_all_words_no_audio_gentle_data.csv",index_col = "Unnamed: 0")

# %% [markdown]
# ## Video files
# - information about entropy of situation in which the homophones was articulated

# %%
#video_data = preprocessing.get_additional_data_from_files(homographs_in_data_celex_merged, "video") # only for homophones
# Out:
# Load and extract information from video files...
# Total files to laod and preprocess:  3645
# File:  0
# File:  100
# File:  200
# File:  300
# File:  400
# File:  500
# File:  600
# File:  700
# File:  800
# File:  900
# File:  1000
# File:  1100
# File:  1200
# File:  1300
# File:  1400
# File:  1500
# File:  1600
# File:  1700
# File:  1800
# File:  1900
# File:  2000
# File:  2100
# File:  2200
# File:  2300
# File:  2400
# File:  2500
# File:  2600
# File:  2700
# File:  2800
# File:  2900
# File:  3000
# File:  3100
# File:  3200
# File:  3300
# File:  3400
# File:  3500
# File:  3600

# %%
#video_data.to_csv("2016_all_words_no_audio_homographs_video_data.csv")

# %%
video_data = pd.read_csv("2016_all_words_no_audio_homographs_video_data.csv",index_col = "Unnamed: 0")

# %% [markdown]
# ## Celex
# - syllable count information

# %%
celex_data = celex_files.get_syl_counts(celex_files.read_celex_file())

# %% [markdown]
# # Word Pronunciation Predictability (Berndt et al. 1987)

# %% [markdown]
# ### Load Berndt's tables for Phoneme Equivalents and Conditional Probabilities for Grapheme-to-Phoneme Correspondences

# %%
berndt_character_code_df = pd.read_csv(berndt_character_coding_file, delimiter=";")
berndt_conditional_probs = pd.read_csv(berndt_conditional_probs_file,delimiter=";")

# %% [markdown]
# ### APPABET to corresponding Keyboard Compatible Phonemic (KCP) symbol dict

# %%
berndt_arpabet_phon_dict = word_pronunciation_predictibility.get_ARPABET_to_keyboard_phonetic_symbols_dict(berndt_character_code_df)

# %% [markdown]
# ### KCP to Grapheme Symbols and Probabilities dict

# %%
phonem_graphem_prob_dict = word_pronunciation_predictibility.get_keyboard_phonetic_symbols_to_grapheme_cond_prob_dict(berndt_conditional_probs)

# %% [markdown]
# ### Homographs with corresponding ARPABET transcription

# %%
unique_homographs = np.unique(homographs_in_data_celex_merged.word)
hom_arpabet_words = word_pronunciation_predictibility.get_ARPABET_phonetic_transcription(unique_homographs)

# %% [markdown]
# ### Homophones with corresponding KCP transcription

# %%
hom_kcp_word_tuples = []
for i,arpabet_word in enumerate(hom_arpabet_words):
    kcp_word = word_pronunciation_predictibility.get_keyboard_phonetic_symbols_for_ARPABET(arpabet_word, berndt_arpabet_phon_dict)
    #print(unique_homophones[i],arpabet_word,kcp_word)
    hom_kcp_word_tuples.append((unique_homographs[i],kcp_word))

# %% [markdown]
# ### Get possible (valid) Grapheme strings and probs for each KCP encoded homograph
# Note: 2 homographs not captured:
# - cause ['k', 'ah', 'z']: the AU-E is coded by aw not ah
#
# Possible Solution:
# - cause ['k', 'aw', 'z']

# %%
possible_grapheme_strings, possible_prior_probs, possible_cond_probs, word_rests = word_pronunciation_predictibility.get_grapheme_string_with_conditional_prob_for_keyboard_phonetics(hom_kcp_word_tuples, 
phonem_graphem_prob_dict)

# %%
# homophones for which we have no valid grapheme string: 
counter = 0 
for i,word_pron in enumerate(hom_kcp_word_tuples):
    word = word_pron[0] # word string
    pron = word_pron[1] # list of keyboard compatible phon characters
    if len(possible_grapheme_strings[i]) == 0 :
        counter+=1
        print(word,pron)
    else:
        empty_string = ['' != i for i in word_rests[i]]
        if np.sum(empty_string) == len(word_rests[i]):
            counter+=1
            print(word,pron)
    
print(counter)
# Out:
# cause ['k', 'ah', 'z']
# 1

# %%
problematic_hom_kcp_word_tuples = [
    ('cause', ['k', 'aw', 'z']),
]

# %%
problematic_hom_kcp_word_tuples_dict = {
    'cause': ('cause', ['k', 'aw', 'z']),
}

# %%
possible_grapheme_strings_problematic_homs, possible_prior_probs_problematic_homs, possible_cond_probs_problematic_homs, word_rests_problematic_homs = word_pronunciation_predictibility.get_grapheme_string_with_conditional_prob_for_keyboard_phonetics(problematic_hom_kcp_word_tuples, 
phonem_graphem_prob_dict)

# %%
j = 0
for i,wp in enumerate(hom_kcp_word_tuples):
    word = wp[0]
    phon = wp[1]
    if word in problematic_hom_kcp_word_tuples_dict:
        possible_grapheme_strings[i] = possible_grapheme_strings_problematic_homs[j]
        word_rests[i] = word_rests_problematic_homs[j]
        possible_prior_probs[i] = possible_prior_probs_problematic_homs[j]
        possible_cond_probs[i] = possible_cond_probs_problematic_homs[j]
        j+=1

# %%
valid_word_rests,valid_grapheme_strings,valid_prior_probs, valid_cond_probs = word_pronunciation_predictibility.get_valid_grapheme_strings(hom_kcp_word_tuples, possible_grapheme_strings, word_rests,possible_prior_probs, possible_cond_probs)

# %%
# homophones for which we have no valid grapheme string: 
counter = 0 
for i,word_pron in enumerate(hom_kcp_word_tuples):
    word = word_pron[0] # word string
    pron = word_pron[1] # list of keyboard compatible phon characters
    if len(valid_grapheme_strings[i]) == 0:
        counter+=1
        print(word,pron)        
print(counter)
# Out:
# 0

# %%
max_cond_prob_for_grapheme = word_pronunciation_predictibility.get_max_cond_prob_for_grapheme(berndt_conditional_probs)

# %%
m_score_data = word_pronunciation_predictibility.get_m_score_df(hom_kcp_word_tuples, valid_grapheme_strings,valid_cond_probs,max_cond_prob_for_grapheme)

# %%
m_score_data
# Out:
#       word   m_score
# 0      act  1.000000
# 1   answer  0.857661
# 2   attack  0.835793
# 3    break  0.761719
# 4     call  0.679582
# ..     ...       ...
# 56   touch  0.695833
# 57    turn  0.797962
# 58    vote  1.000000
# 59   waste  1.000000
# 60    work  0.792197
#
# [61 rows x 2 columns]

# %% [markdown]
# # Merging Dataframes

# %%
homographs_in_data_celex_merged

# %%
import importlib
importlib.reload(merging_dataframes)
# Out:
# <module 'merging_dataframes' from '/mnt/Restricted/Corpora/RedHen/homophone_analysis_scripts/merging_dataframes.py'>

# %% [markdown]
# ### Merging eaf data

# %%
homographs_in_data_celex_eaf = merging_dataframes.merge_eaf_df_to_homophone_data(homographs_in_data_celex_merged, eaf_data)
# Out:
# 1  /  3645
# 101  /  3645
# 201  /  3645
# 301  /  3645
# 401  /  3645
# 501  /  3645
# 601  /  3645
# 701  /  3645
# 801  /  3645
# 901  /  3645
# 1001  /  3645
# 1101  /  3645
# 1201  /  3645
# 1301  /  3645
# 1401  /  3645
# 1501  /  3645
# 1601  /  3645
# 1701  /  3645
# 1801  /  3645
# 1901  /  3645
# 2001  /  3645
# 2101  /  3645
# 2201  /  3645
# 2301  /  3645
# 2401  /  3645
# 2501  /  3645
# 2601  /  3645
# 2701  /  3645
# 2801  /  3645
# 2901  /  3645
# 3001  /  3645
# 3101  /  3645
# 3201  /  3645
# 3301  /  3645
# 3401  /  3645
# 3501  /  3645
# 3601  /  3645

# %%
len(homographs_in_data_celex_eaf)

# %% [markdown]
# ### Merging video data

# %%
homographs_in_data_celex_eaf_video = merging_dataframes.merge_video_df_to_homophone_data(homographs_in_data_celex_eaf, video_data)

# %%
len(homophones_in_data_celex_eaf_video)

# %% [markdown]
# ### Merging gentle data

# %%
homographs_in_data_celex_eaf_video_gentle = merging_dataframes.merge_gentle_df_to_homophone_data(homographs_in_data_celex_eaf_video, gentle_data)
# Out:
# Merge gentle data for 3645 unique files!
# File:  0
# File:  100
# File:  200
# File:  300
# File:  400
# File:  500
# File:  600
# File:  700
# File:  800
# File:  900
# File:  1000
# File:  1100
# File:  1200
# File:  1300
# File:  1400
# File:  1500
# File:  1600
# File:  1700
# File:  1800
# File:  1900
# File:  2000
# File:  2100
# File:  2200
# File:  2300
# File:  2400
# File:  2500
# File:  2600
# File:  2700
# File:  2800
# File:  2900
# File:  3000
# File:  3100
# File:  3200
# File:  3300
# File:  3400
# File:  3500
# File:  3600

# %%
len(homographs_in_data_celex_eaf_video_gentle)

# %% [markdown]
# ### Merging seg data

# %%
homographs_in_data_celex_eaf_video_gentle_seg = merging_dataframes.merge_seg_df_to_homophone_data(homographs_in_data_celex_eaf_video_gentle, seg_data)
# Out:
# Merge seg data for 3645 unique files!
# File:  0
# File:  100
# File:  200
# File:  300
# File:  400
# File:  500
# File:  600
# File:  700
# File:  800
# File:  900
# File:  1000
# File:  1100
# File:  1200
# File:  1300
# File:  1400
# File:  1500
# File:  1600
# File:  1700
# File:  1800
# File:  1900
# File:  2000
# File:  2100
# File:  2200
# File:  2300
# File:  2400
# File:  2500
# File:  2600
# File:  2700
# File:  2800
# File:  2900
# File:  3000
# File:  3100
# File:  3200
# File:  3300
# File:  3400
# File:  3500
# File:  3600

# %%
len(homographs_in_data_celex_eaf_video_gentle_seg)

# %% [markdown]
# ### Merging m-scores data

# %%
homographs_in_data_celex_eaf_video_gentle_seg_m_scores = merging_dataframes.merge_m_scores_df_to_homophone_data(homographs_in_data_celex_eaf_video_gentle_seg,m_score_data)

# %% [markdown]
# ### Merging celex syllable counts data

# %%
homographs_in_data_celex_eaf_video_gentle_seg_m_scores_syll = merging_dataframes.merge_celex_syl_counts_df_to_homophone_data(homographs_in_data_celex_eaf_video_gentle_seg_m_scores,celex_data)

# %%
homographs_in_data_celex_eaf_video_gentle_seg_m_scores_syll
# Out:
#                                               source_file   word    start  \
# 0                  2016-01-01_0100_US_KNBC_Channel_4_News   fire    21.75
# 1                  2016-01-01_0100_US_KNBC_Channel_4_News   fire    46.35
# 2                  2016-01-01_0100_US_KNBC_Channel_4_News   fire    48.07
# 3                  2016-01-01_0100_US_KNBC_Channel_4_News   fire    68.99
# 4                  2016-01-01_0100_US_KNBC_Channel_4_News   fire    99.12
# ...                                                   ...    ...      ...
# 294813  2016-12-29_1400_US_CNN_CNN_Newsroom_With_Carol...  dress   182.11
# 294814  2016-12-29_1500_US_CNN_CNN_Newsroom_With_Carol...  dress  1350.66
# 294815  2016-12-31_0230_US_KCBS_CBS_Evening_News_With_...  dress  1550.44
# 294816                2016-12-31_1300_US_MSNBC_MSNBC_Live  dress   674.31
# 294817                2016-12-31_1300_US_MSNBC_MSNBC_Live  dress  1024.45
#
#                 end  duration       label_type mp4_error aac_error  \
# 0         22.110000      0.36  high-confidence  no-error  no-error
# 1         46.879999      0.53  high-confidence  no-error  no-error
# 2         48.290000      0.22  high-confidence  no-error  no-error
# 3         69.380000      0.39  high-confidence  no-error  no-error
# 4         99.370000      0.25  high-confidence  no-error  no-error
# ...             ...       ...              ...       ...       ...
# 294813   182.440000      0.33  high-confidence  no-error  no-error
# 294814  1351.050000      0.39  high-confidence  no-error  no-error
# 294815  1550.730000      0.29  high-confidence  no-error  no-error
# 294816   674.609999      0.30  high-confidence  no-error  no-error
# 294817  1024.739999      0.29  high-confidence  no-error  no-error
#
#        aac2wav_error eafgz_error  ... seg_preceding_marker  \
# 0           no-error    no-error  ...                False
# 1           no-error    no-error  ...                False
# 2           no-error    no-error  ...                False
# 3           no-error    no-error  ...                False
# 4           no-error    no-error  ...                False
# ...              ...         ...  ...                  ...
# 294813      no-error    no-error  ...                False
# 294814      no-error    no-error  ...                False
# 294815      no-error    no-error  ...                  NaN
# 294816      no-error    no-error  ...                False
# 294817      no-error    no-error  ...                False
#
#         seg_subsequent_marker      seg_merging   seg_index  pos  rel1   rel2  \
# 0                       False  high-confidence        83.0   NN  I-NP      O
# 1                        True  high-confidence       161.0   NN  I-NP  I-PNP
# 2                       False  high-confidence       164.0   NN  I-NP      O
# 3                       False  high-confidence       240.0   NN  I-NP      O
# 4                       False  high-confidence       317.0  WDT  I-NP      O
# ...                       ...              ...         ...  ...   ...    ...
# 294813                  False  high-confidence  22092644.0   NN  I-NP      O
# 294814                  False  high-confidence  22105392.0   NN  I-NP  I-PNP
# 294815                    NaN              NaN         NaN  NaN   NaN    NaN
# 294816                  False  high-confidence  22303686.0   NN  I-NP  I-PNP
# 294817                   True  high-confidence  22304575.0   NN  I-NP  I-PNP
#
#         lemma  m_score SylCnt
# 0        fire    0.863      2
# 1        fire    0.863      2
# 2        fire    0.863      2
# 3        fire    0.863      2
# 4        FIRE    0.863      2
# ...       ...      ...    ...
# 294813  dress    1.000      1
# 294814  dress    1.000      1
# 294815    NaN    1.000      1
# 294816  dress    1.000      1
# 294817  dress    1.000      1
#
# [294818 rows x 63 columns]

# %%
homographs_in_data_celex_eaf_video_gentle_seg_m_scores_syll.to_csv("2016_all_words_no_audio_homographs_preprocessed.csv")

# %% [markdown]
# ### Merging Model Predictions for conditional predictibality of Homophones
# - missing TODO

# %%
model_predictions = pd.read_csv("conditional_prob_of_homophones_model_predictions.csv",index_col = "Unnamed: 0")

# %%
model_predictions.drop_duplicates(subset = ["prev_word", "homophone", "next_word"], inplace = True)
model_predictions.rename(columns= {"homophone": "word", "prev_prob": "prob|prev_model", "next_prob" : "prob|next_model"}, inplace=True)

# %%
homographs_in_data_celex_eaf_video_gentle_seg_m_scores_syll_model_predictions = homographs_in_data_celex_eaf_video_gentle_seg_m_scores_syll.merge(model_predictions, on = ["prev_word", "word", "next_word"])

# %%
homographs_in_data_celex_eaf_video_gentle_seg_m_scores_syll_model_predictions.columns

# %%
homographs_in_data_celex_eaf_video_gentle_seg_m_scores_syll_model_predictions.rename(columns= {"cond_pred_prev": "prob|prev_text", "cond_pred_next" : "prob|next_text"}, inplace=True)

# %% [markdown]
# # Homographs merged with low confidence

# %%
preprocessed_df = pd.read_csv("2016_all_words_no_audio_homographs_preprocessed.csv",index_col = "Unnamed: 0")

# %%
low_confidence_homs = preprocessed_df[np.logical_or(preprocessed_df.seg_merging == "low-confidence",preprocessed_df.gentle_merging == "low-confidence")]

# %%
low_confidence_homs[["word", 'prev_word', 'next_word', 'gentle_prev_word', 'gentle_next_word', 'seg_prev_word', 'seg_next_word',"seg_error",'eafgz_error','preceding_pause','subsequent_pause']]
# Out:
#          word prev_word next_word gentle_prev_word gentle_next_word  \
# 21       fire     hotel     holly            hotel            holly
# 52       fire      open      with             open             with
# 71       fire        on       who               on              who
# 74       fire        in       the              the              the
# 96       fire      down       and              the              and
# ...       ...       ...       ...              ...              ...
# 294769  dress    icon's      sold           icon's             sold
# 294791  dress   woman's   stained          woman's          stained
# 294792  dress      term       for               ``              for
# 294799  dress        to    garang               to           garang
# 294805  dress         a   melania                a              for
#
#        seg_prev_word seg_next_word seg_error eafgz_error  preceding_pause  \
# 21             hotel       quijano  no-error    no-error            False
# 52              open      reporter  no-error    no-error             True
# 71                on      reporter  no-error    no-error            False
# 74               the           the  no-error    no-error            False
# 96               the           and  no-error    no-error            False
# ...              ...           ...       ...         ...              ...
# 294769            's          sold  no-error    no-error             True
# 294791            's       stained  no-error    no-error            False
# 294792             "           for  no-error    no-error            False
# 294799            to      reporter  no-error    no-error            False
# 294805             a           for  no-error    no-error            False
#
#         subsequent_pause
# 21                  True
# 52                 False
# 71                 False
# 74                  True
# 96                 False
# ...                  ...
# 294769             False
# 294791              True
# 294792             False
# 294799             False
# 294805             False
#
# [21703 rows x 11 columns]

# %%
#subset = ["word", "prev_word", "next_word", "gentle_prev_word", "gentle_next_word", "seg_prev_word", "seg_next_word"]
low_confidence_homs.drop_duplicates()[["word", 'prev_word', 'next_word', 'gentle_prev_word', 'gentle_next_word', 'seg_prev_word', 'seg_next_word','preceding_pause','subsequent_pause']]
# Out:
#          word prev_word next_word gentle_prev_word gentle_next_word  \
# 21       fire     hotel     holly            hotel            holly
# 52       fire      open      with             open             with
# 71       fire        on       who               on              who
# 74       fire        in       the              the              the
# 96       fire      down       and              the              and
# ...       ...       ...       ...              ...              ...
# 294769  dress    icon's      sold           icon's             sold
# 294791  dress   woman's   stained          woman's          stained
# 294792  dress      term       for               ``              for
# 294799  dress        to    garang               to           garang
# 294805  dress         a   melania                a              for
#
#        seg_prev_word seg_next_word  preceding_pause  subsequent_pause
# 21             hotel       quijano            False              True
# 52              open      reporter             True             False
# 71                on      reporter            False             False
# 74               the           the            False              True
# 96               the           and            False             False
# ...              ...           ...              ...               ...
# 294769            's          sold             True             False
# 294791            's       stained            False              True
# 294792             "           for            False             False
# 294799            to      reporter            False             False
# 294805             a           for            False             False
#
# [21703 rows x 9 columns]

# %% [markdown]
# ## Seg Data

# %%
low_confidence_homs_seg = preprocessed_df[preprocessed_df.seg_merging == "low-confidence"][["word", 'prev_word', 'next_word', 'seg_prev_word', 'seg_next_word','preceding_pause','subsequent_pause']]
#low_confidence_homs_seg.drop_duplicates(subset = ["word", "prev_word", "next_word", "gentle_prev_word", "gentle_next_word", "seg_prev_word", "seg_next_word"])[["word", 'prev_word', 'next_word', 'seg_prev_word', 'seg_next_word','preceding_pause','subsequent_pause'], inplace = True]
low_confidence_homs_seg
# Out:
#          word prev_word next_word seg_prev_word seg_next_word  \
# 21       fire     hotel     holly         hotel       quijano
# 52       fire      open      with          open      reporter
# 71       fire        on       who            on      reporter
# 74       fire        in       the           the           the
# 96       fire      down       and           the           and
# ...       ...       ...       ...           ...           ...
# 294769  dress    icon's      sold            's          sold
# 294791  dress   woman's   stained            's       stained
# 294792  dress      term       for             "           for
# 294799  dress        to    garang            to      reporter
# 294805  dress         a   melania             a           for
#
#         preceding_pause  subsequent_pause
# 21                False              True
# 52                 True             False
# 71                False             False
# 74                False              True
# 96                False             False
# ...                 ...               ...
# 294769             True             False
# 294791            False              True
# 294792            False             False
# 294799            False             False
# 294805            False             False
#
# [21268 rows x 7 columns]

# %% [markdown]
# ## Gentle Data

# %%
low_confidence_homs_gentle = preprocessed_df[preprocessed_df.gentle_merging == "low-confidence"][["word", 'prev_word', 'next_word',"gentle_prev_word", "gentle_next_word" ,'preceding_pause','subsequent_pause']]
#low_confidence_homs_gentle.drop_duplicates(subset = ["word", "prev_word", "next_word", "gentle_prev_word", "gentle_next_word"])[["word", 'prev_word', 'next_word',"gentle_prev_word", "gentle_next_word" ,'preceding_pause','subsequent_pause']]
low_confidence_homs_gentle
# Out:
#          word prev_word     next_word gentle_prev_word gentle_next_word  \
# 74       fire        in           the              the              the
# 96       fire      down           and              the              and
# 115      fire        on        rating               on               ''
# 125      fire         a       captain             l.a.          captain
# 126      fire         a  department's             l.a.     department's
# ...       ...       ...           ...              ...              ...
# 294744  dress   islamic         codes          islamic          codes.s
# 294753  dress       not           mrs              not             mrs.
# 294760  dress       the           all              the              and
# 294792  dress      term           for               ``              for
# 294805  dress         a       melania                a              for
#
#         preceding_pause  subsequent_pause
# 74                False              True
# 96                False             False
# 115               False             False
# 125               False             False
# 126               False             False
# ...                 ...               ...
# 294744            False             False
# 294753            False             False
# 294760            False             False
# 294792            False             False
# 294805            False             False
#
# [14288 rows x 7 columns]

# %% [markdown]
# # Find Substrings
# Because of differences in splitting it might happen that only a subpart of the word is listed in prev-/ next-word columns. Check wether the previous word column ends with the same string and check wether the next column starts with the same string.

# %% [markdown]
# ## Seg Data

# %% [markdown]
# ### Prev word

# %%
low_confidence_homs_seg_because_prev_word = low_confidence_homs_seg[low_confidence_homs_seg.seg_prev_word != low_confidence_homs_seg.prev_word]
print(len(low_confidence_homs_seg_because_prev_word))
matched_prev_word_substring_seg = low_confidence_homs_seg_because_prev_word.apply(lambda row: str(row.seg_prev_word).endswith(str(row.prev_word)) or str(row.prev_word).endswith(str(row.seg_prev_word)), axis = 1)
low_confidence_homs_seg_because_prev_word[matched_prev_word_substring_seg]
#low_confidence_homs_seg[low_confidence_homs_seg.apply(lambda row: str(row.seg_prev_word) in str(row.prev_word) or str(row.prev_word) in str(row.seg_prev_word), axis = 1)]
# Out:
# 11592
#          word  prev_word    next_word seg_prev_word seg_next_word  \
# 361      fire  clinton's         wall            's          wall
# 552      fire    plane's  suppression            's   suppression
# 610      fire  clinton's         wall            's          wall
# 656      fire    solon's    battalion            's     battalion
# 708      fire    rubio's         wall            's          wall
# ...       ...        ...          ...           ...           ...
# 293581  study    today's    suggested            's     suggested
# 293713  study        com            a  bankrate.com             a
# 293823  study   school's       abroad            's        abroad
# 294769  dress     icon's         sold            's          sold
# 294791  dress    woman's      stained            's       stained
#
#         preceding_pause  subsequent_pause
# 361               False             False
# 552               False             False
# 610               False             False
# 656                True             False
# 708               False             False
# ...                 ...               ...
# 293581            False             False
# 293713            False              True
# 293823            False             False
# 294769             True             False
# 294791            False              True
#
# [3040 rows x 7 columns]

# %% [markdown]
# ### Next word

# %%
low_confidence_homs_seg_because_next_word = low_confidence_homs_seg[low_confidence_homs_seg.seg_next_word != low_confidence_homs_seg.next_word]
print(len(low_confidence_homs_seg_because_next_word))
matched_next_word_substring_seg = low_confidence_homs_seg_because_next_word.apply(lambda row: str(row.seg_next_word).startswith(str(row.next_word)) or str(row.next_word).startswith(str(row.seg_next_word)), axis = 1)
low_confidence_homs_seg_because_next_word[matched_next_word_substring_seg]
# Out:
# 10421
#          word prev_word     next_word seg_prev_word seg_next_word  \
# 126      fire         a  department's          l.a.    department
# 754      fire         a             a             a           and
# 816      fire     opens             a         opens            at
# 878      fire   there's       there's            's         there
# 1332     fire         a           the             a          then
# ...       ...       ...           ...           ...           ...
# 292792  waste       and            it           and         it.ep
# 293244  study     study             i         study            i.
# 294282  study       new             a           new        a.a.a.
# 294744  dress   islamic         codes       islamic       codes.s
# 294753  dress       not           mrs           not          mrs.
#
#         preceding_pause  subsequent_pause
# 126               False             False
# 754               False             False
# 816               False             False
# 878                True              True
# 1332              False             False
# ...                 ...               ...
# 292792            False             False
# 293244            False             False
# 294282            False             False
# 294744            False             False
# 294753            False             False
#
# [917 rows x 7 columns]

# %% [markdown]
# ## Gentle Data

# %% [markdown]
# ### Prev word

# %%
low_confidence_homs_gentle_because_prev_word = low_confidence_homs_gentle[low_confidence_homs_gentle.gentle_prev_word != low_confidence_homs_gentle.prev_word]
print(len(low_confidence_homs_gentle_because_prev_word))
matched_prev_word_substring_gentle = low_confidence_homs_gentle_because_prev_word.apply(lambda row: str(row.gentle_prev_word).endswith(str(row.prev_word)) or str(row.prev_word).endswith(str(row.gentle_prev_word)), axis = 1)
low_confidence_homs_gentle_because_prev_word[matched_prev_word_substring_gentle]
#low_confidence_homs_seg[low_confidence_homs_seg.apply(lambda row: str(row.seg_prev_word) in str(row.prev_word) or str(row.prev_word) in str(row.seg_prev_word), axis = 1)]
# Out:
# 6747
#          word prev_word   next_word gentle_prev_word gentle_next_word  \
# 1035     fire        oh     they're            uh-oh            aaagh
# 1081     fire     alarm         the      three-alarm              and
# 3626     fire    moving         out      fast-moving           barely
# 7609     show       000          up          200,000               up
# 7745     show      free           9  commercial-free             9:00
# ...       ...       ...         ...              ...              ...
# 289430   sign       com          up   myheritage.com               up
# 289451   sign       com          up   myheritage.com               up
# 289696   sign       com          up   myheritage.com               up
# 293069  waste        24  management            36.24       management
# 293713  study       com           a     bankrate.com                a
#
#         preceding_pause  subsequent_pause
# 1035              False              True
# 1081              False             False
# 3626              False             False
# 7609              False             False
# 7745              False             False
# ...                 ...               ...
# 289430             True             False
# 289451             True             False
# 289696             True             False
# 293069             True             False
# 293713            False              True
#
# [273 rows x 7 columns]

# %% [markdown]
# ### Next word

# %%
low_confidence_homs_gentle_because_next_word = low_confidence_homs_gentle[low_confidence_homs_gentle.gentle_next_word != low_confidence_homs_gentle.next_word]
print(len(low_confidence_homs_gentle_because_next_word))
matched_next_word_substring_gentle = low_confidence_homs_gentle_because_next_word.apply(lambda row: str(row.gentle_next_word).startswith(str(row.next_word)) or str(row.next_word).startswith(str(row.gentle_next_word)), axis = 1)
low_confidence_homs_gentle_because_next_word[matched_next_word_substring_gentle]
# Out:
# 7603
#          word prev_word next_word gentle_prev_word gentle_next_word  \
# 754      fire         a         a                a              and
# 816      fire     opens         a            opens               at
# 1332     fire         a       the                a             then
# 1723     fire    sniper         u           sniper         u.s.-led
# 1873     fire     brush         l            brush             l.a.
# ...       ...       ...       ...              ...              ...
# 292792  waste       and        it              and            it.ep
# 293244  study     study         i            study               i.
# 294282  study       new         a              new           a.a.a.
# 294744  dress   islamic     codes          islamic          codes.s
# 294753  dress       not       mrs              not             mrs.
#
#         preceding_pause  subsequent_pause
# 754               False             False
# 816               False             False
# 1332              False             False
# 1723              False             False
# 1873              False              True
# ...                 ...               ...
# 292792            False             False
# 293244            False             False
# 294282            False             False
# 294744            False             False
# 294753            False             False
#
# [517 rows x 7 columns]

# %% [markdown]
# ## Change merging confidence to medium

# %%
low_confidence_homs["matched_prev_word_substring_seg"] = np.nan
low_confidence_homs["matched_next_word_substring_seg"] = np.nan
low_confidence_homs["matched_prev_word_substring_gentle"] = np.nan
low_confidence_homs["matched_next_word_substring_gentle"] = np.nan
# Out:
# <ipython-input-52-a96f3fba8bfc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   low_confidence_homs["matched_prev_word_substring_seg"] = np.nan
# <ipython-input-52-a96f3fba8bfc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   low_confidence_homs["matched_next_word_substring_seg"] = np.nan
# <ipython-input-52-a96f3fba8bfc>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   low_confidence_homs["matched_prev_word_substring_gentle"] = np.nan
# <ipython-input-52-a96f3fba8bfc>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   low_confidence_homs["matched_next_word_substring_gentle"] = np.nan

# %%
low_confidence_homs
# Out:
#                                               source_file   word    start  \
# 21               2016-01-01_0229_US_KCBS_CBS_Evening_News   fire   133.54
# 52                 2016-01-02_0200_UK_KCET_BBC_World_News   fire   964.47
# 71               2016-01-02_0230_US_KNBC_NBC_Nightly_News   fire  1697.64
# 74         2016-01-02_0700_US_KNBC_Channel_4_News_at_11PM   fire   392.87
# 96                     2016-01-04_0735_US_KNBC_NBC_4_News   fire   218.01
# ...                                                   ...    ...      ...
# 294769  2016-11-19_0230_US_KCBS_CBS_Evening_News_With_...  dress  1179.20
# 294791           2016-12-19_0130_US_KCBS_CBS_Weekend_News  dress   637.00
# 294792     2016-12-19_0700_US_KNBC_Channel_4_News_at_11PM  dress   927.99
# 294799                  2016-12-22_0837_US_KABC_Nightline  dress  1082.80
# 294805                  2016-12-22_0837_US_KABC_Nightline  dress  1277.46
#
#                 end  duration       label_type mp4_error aac_error  \
# 21       134.000000      0.46  high-confidence  no-error  no-error
# 52       964.610000      0.14   low-confidence  no-error  no-error
# 71      1697.920000      0.28  high-confidence  no-error  no-error
# 74       393.290000      0.42  high-confidence  no-error  no-error
# 96       218.620000      0.61  high-confidence  no-error  no-error
# ...             ...       ...              ...       ...       ...
# 294769  1179.740000      0.54  high-confidence  no-error  no-error
# 294791   637.430000      0.43  high-confidence  no-error  no-error
# 294792   928.370000      0.38  high-confidence  no-error  no-error
# 294799  1083.160000      0.36  high-confidence  no-error  no-error
# 294805  1277.809999      0.35  high-confidence  no-error  no-error
#
#        aac2wav_error eafgz_error  ... pos  rel1   rel2  lemma m_score  SylCnt  \
# 21          no-error    no-error  ...  NN  I-NP  I-PNP   fire   0.863       2
# 52          no-error    no-error  ...  NN  I-NP  I-PNP   fire   0.863       2
# 71          no-error    no-error  ...  NN  I-NP  I-PNP   fire   0.863       2
# 74          no-error    no-error  ...  NN  I-NP  I-PNP   fire   0.863       2
# 96          no-error    no-error  ...  NN  I-NP  I-PNP   fire   0.863       2
# ...              ...         ...  ...  ..   ...    ...    ...     ...     ...
# 294769      no-error    no-error  ...  NN  I-NP      O  dress   1.000       1
# 294791      no-error    no-error  ...  NN  I-NP      O  dress   1.000       1
# 294792      no-error    no-error  ...  NN  I-NP      O  dress   1.000       1
# 294799      no-error    no-error  ...  VB  I-VP      O  dress   1.000       1
# 294805      no-error    no-error  ...  NN  I-NP      O  dress   1.000       1
#
#        matched_prev_word_substring_seg  matched_next_word_substring_seg  \
# 21                                 NaN                              NaN
# 52                                 NaN                              NaN
# 71                                 NaN                              NaN
# 74                                 NaN                              NaN
# 96                                 NaN                              NaN
# ...                                ...                              ...
# 294769                             NaN                              NaN
# 294791                             NaN                              NaN
# 294792                             NaN                              NaN
# 294799                             NaN                              NaN
# 294805                             NaN                              NaN
#
#         matched_prev_word_substring_gentle matched_next_word_substring_gentle
# 21                                     NaN                                NaN
# 52                                     NaN                                NaN
# 71                                     NaN                                NaN
# 74                                     NaN                                NaN
# 96                                     NaN                                NaN
# ...                                    ...                                ...
# 294769                                 NaN                                NaN
# 294791                                 NaN                                NaN
# 294792                                 NaN                                NaN
# 294799                                 NaN                                NaN
# 294805                                 NaN                                NaN
#
# [21703 rows x 67 columns]

# %%
low_confidence_homs.loc[matched_prev_word_substring_seg.index,"matched_prev_word_substring_seg"] = matched_prev_word_substring_seg.replace(False,-1)
low_confidence_homs.loc[matched_next_word_substring_seg.index,"matched_next_word_substring_seg"] = matched_next_word_substring_seg.replace(False,-1)
low_confidence_homs.loc[matched_prev_word_substring_gentle.index,"matched_prev_word_substring_gentle"] = matched_prev_word_substring_gentle.replace(False,-1)
low_confidence_homs.loc[matched_next_word_substring_gentle.index,"matched_next_word_substring_gentle"] = matched_next_word_substring_gentle.replace(False,-1)
# Out:
# /home/paul/anaconda3/envs/bon18/lib/python3.8/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
low_confidence_homs["matched_prev_word_substring_seg"] = low_confidence_homs["matched_prev_word_substring_seg"].replace(np.nan,0)
low_confidence_homs["matched_next_word_substring_seg"] = low_confidence_homs["matched_next_word_substring_seg"].replace(np.nan,0)
low_confidence_homs["matched_prev_word_substring_gentle"] = low_confidence_homs["matched_prev_word_substring_gentle"].replace(np.nan,0)
low_confidence_homs["matched_next_word_substring_gentle"] = low_confidence_homs["matched_next_word_substring_gentle"].replace(np.nan,0)
# Out:
# <ipython-input-55-b39035a6ad41>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   low_confidence_homs["matched_prev_word_substring_seg"] = low_confidence_homs["matched_prev_word_substring_seg"].replace(np.nan,0)
# <ipython-input-55-b39035a6ad41>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   low_confidence_homs["matched_next_word_substring_seg"] = low_confidence_homs["matched_next_word_substring_seg"].replace(np.nan,0)
# <ipython-input-55-b39035a6ad41>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   low_confidence_homs["matched_prev_word_substring_gentle"] = low_confidence_homs["matched_prev_word_substring_gentle"].replace(np.nan,0)
# <ipython-input-55-b39035a6ad41>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   low_confidence_homs["matched_next_word_substring_gentle"] = low_confidence_homs["matched_next_word_substring_gentle"].replace(np.nan,0)

# %%
low_confidence_homs[["matched_prev_word_substring_seg","matched_next_word_substring_seg","matched_prev_word_substring_gentle", "matched_next_word_substring_gentle"]]
# Out:
#         matched_prev_word_substring_seg  matched_next_word_substring_seg  \
# 21                                  0.0                             -1.0
# 52                                  0.0                             -1.0
# 71                                  0.0                             -1.0
# 74                                 -1.0                              0.0
# 96                                 -1.0                              0.0
# ...                                 ...                              ...
# 294769                              1.0                              0.0
# 294791                              1.0                              0.0
# 294792                             -1.0                              0.0
# 294799                              0.0                             -1.0
# 294805                              0.0                             -1.0
#
#         matched_prev_word_substring_gentle  matched_next_word_substring_gentle
# 21                                     0.0                                 0.0
# 52                                     0.0                                 0.0
# 71                                     0.0                                 0.0
# 74                                    -1.0                                 0.0
# 96                                    -1.0                                 0.0
# ...                                    ...                                 ...
# 294769                                 0.0                                 0.0
# 294791                                 0.0                                 0.0
# 294792                                -1.0                                 0.0
# 294799                                 0.0                                 0.0
# 294805                                 0.0                                -1.0
#
# [21703 rows x 4 columns]

# %%
medium_confidence_seg = low_confidence_homs[low_confidence_homs["matched_prev_word_substring_seg"] + low_confidence_homs["matched_next_word_substring_seg"] > 0].index

# %%
medium_confidence_gentle = low_confidence_homs[low_confidence_homs["matched_prev_word_substring_gentle"] + low_confidence_homs["matched_next_word_substring_gentle"] > 0].index

# %%
preprocessed_df.loc[medium_confidence_seg,"seg_merging"] = "medium-confidence"
preprocessed_df.loc[medium_confidence_gentle,"gentle_merging"] = "medium-confidence"

# %% [markdown]
# # Remaining Low confidence homophones

# %%
#preprocessed_df = pd.read_csv("2016_all_words_no_audio_preprocessed.csv",index_col = "Unnamed: 0")

# %%
remaining_low_confidence_homs = preprocessed_df[np.logical_or(preprocessed_df.seg_merging == "low-confidence",preprocessed_df.gentle_merging == "low-confidence")]

# %%
remaining_low_confidence_homs[["word", 'prev_word', 'next_word', 'gentle_prev_word', 'gentle_next_word', 'seg_prev_word', 'seg_next_word',"seg_error",'eafgz_error','preceding_pause','subsequent_pause']]
# Out:
#          word prev_word next_word gentle_prev_word gentle_next_word  \
# 21       fire     hotel     holly            hotel            holly
# 52       fire      open      with             open             with
# 71       fire        on       who               on              who
# 74       fire        in       the              the              the
# 96       fire      down       and              the              and
# ...       ...       ...       ...              ...              ...
# 294743  dress     can't      that            can't             that
# 294760  dress       the       all              the              and
# 294792  dress      term       for               ``              for
# 294799  dress        to    garang               to           garang
# 294805  dress         a   melania                a              for
#
#        seg_prev_word seg_next_word seg_error eafgz_error  preceding_pause  \
# 21             hotel       quijano  no-error    no-error            False
# 52              open      reporter  no-error    no-error             True
# 71                on      reporter  no-error    no-error            False
# 74               the           the  no-error    no-error            False
# 96               the           and  no-error    no-error            False
# ...              ...           ...       ...         ...              ...
# 294743           not          that  no-error    no-error            False
# 294760           the           and  no-error    no-error            False
# 294792             "           for  no-error    no-error            False
# 294799            to      reporter  no-error    no-error            False
# 294805             a           for  no-error    no-error            False
#
#         subsequent_pause
# 21                  True
# 52                 False
# 71                 False
# 74                  True
# 96                 False
# ...                  ...
# 294743             False
# 294760             False
# 294792             False
# 294799             False
# 294805             False
#
# [18128 rows x 11 columns]

# %%
remaining_low_confidence_homs.columns
# Out:
# Index(['source_file', 'word', 'start', 'end', 'duration', 'label_type',
#        'mp4_error', 'aac_error', 'aac2wav_error', 'eafgz_error', 'seg_error',
#        'preceding_pause', 'subsequent_pause', 'word_frequency', 'prev_word',
#        'prev_word_frequency', 'next_word', 'next_word_frequency',
#        'length_in_letter', 'prev_word_string', 'next_word_string',
#        'prev_word_string_frequency', 'next_word_string_frequency',
#        'cond_pred_prev', 'cond_pred_next', 'disc', 'clx', 'disc_no_bound',
#        'clx_no_bound', 'gesture', 'HandMoving', 'PersonOnScreen',
#        'SpeakerOnScreen', 'HeadMoving/MovingVertically',
#        'ShoulderMoving/NotWithHead', 'HeadMoving/MovingHorizontally',
#        'ShoulderMoving/NoSlidingWindow', 'none',
#        'ShoulderMoving/SlidingWindow', 'is_gesture', 'video_snippet_size',
#        'gentle_prev_word', 'gentle_next_word', 'gentle_end_of_sentence',
#        'gentle_start_of_sentence', 'gentle_preceding_marker',
#        'gentle_subsequent_marker', 'gentle_merging', 'gentle_index',
#        'seg_prev_word', 'seg_next_word', 'seg_end_of_sentence',
#        'seg_start_of_sentence', 'seg_preceding_marker',
#        'seg_subsequent_marker', 'seg_merging', 'seg_index', 'pos', 'rel1',
#        'rel2', 'lemma', 'm_score', 'SylCnt'],
#       dtype='object')

# %%
remaining_low_confidence_homs[["preceding_pause", "subsequent_pause", "gentle_start_of_sentence", "gentle_end_of_sentence", "seg_start_of_sentence", "seg_end_of_sentence","seg_preceding_marker",
       "seg_subsequent_marker", "gentle_preceding_marker","gentle_subsequent_marker"]]
# Out:
#         preceding_pause  subsequent_pause gentle_start_of_sentence  \
# 21                False              True                    False
# 52                 True             False                    False
# 71                False             False                    False
# 74                False              True                    False
# 96                False             False                    False
# ...                 ...               ...                      ...
# 294743            False             False                    False
# 294760            False             False                    False
# 294792            False             False                    False
# 294799            False             False                    False
# 294805            False             False                    False
#
#        gentle_end_of_sentence seg_start_of_sentence seg_end_of_sentence  \
# 21                       True                 False                True
# 52                      False                 False                True
# 71                       True                 False                True
# 74                       True                 False                True
# 96                      False                 False               False
# ...                       ...                   ...                 ...
# 294743                  False                 False               False
# 294760                  False                 False               False
# 294792                  False                 False               False
# 294799                   True                 False                True
# 294805                  False                 False               False
#
#        seg_preceding_marker seg_subsequent_marker gentle_preceding_marker  \
# 21                    False                  True                   False
# 52                    False                  True                   False
# 71                    False                  True                   False
# 74                    False                  True                   False
# 96                    False                 False                   False
# ...                     ...                   ...                     ...
# 294743                False                 False                   False
# 294760                False                 False                   False
# 294792                False                 False                   False
# 294799                False                  True                   False
# 294805                False                 False                   False
#
#        gentle_subsequent_marker
# 21                         True
# 52                        False
# 71                         True
# 74                         True
# 96                        False
# ...                         ...
# 294743                    False
# 294760                    False
# 294792                    False
# 294799                     True
# 294805                    False
#
# [18128 rows x 10 columns]

# %%
not_index = preprocessed_df.index.isin(remaining_low_confidence_homs.index)
high_confidence_homs = preprocessed_df[~not_index]

# %%
medium_confidence_homs = preprocessed_df[np.logical_or(preprocessed_df.seg_merging == "medium-confidence",preprocessed_df.gentle_merging == "medium-confidence")]

# %%
print("High Confidence rows: ", len(high_confidence_homs)-len(medium_confidence_homs))
print("Medium Confidence rows: ", len(medium_confidence_homs))
print("Low Confidence rows: ", len(remaining_low_confidence_homs))
print("------------------------------------------------")
print(len(preprocessed_df), "Dataframe rows") 
print(len(remaining_low_confidence_homs)/len(preprocessed_df) * 100, "%")
# Out:
# High Confidence rows:  273061
# Medium Confidence rows:  3629
# Low Confidence rows:  18128
# ------------------------------------------------
# 294818 Dataframe rows
# 6.148878291013439 %

# %%
preprocessed_df[np.logical_or(preprocessed_df.seg_merging == "medium-confidence",preprocessed_df.gentle_merging == "medium-confidence")]
# Out:
#                                               source_file   word    start  \
# 361              2016-01-20_0230_US_KNBC_NBC_Nightly_News   fire   377.14
# 552              2016-02-11_0230_US_KNBC_NBC_Nightly_News   fire   657.74
# 610     2016-02-16_1700_US_CNN_Legal_View_With_Ashleig...   fire  1375.60
# 656          2016-02-19_2302_US_WEWS_NewsChannel_5_at_6pm   fire   740.28
# 708     2016-02-24_2000_US_FOX-News_Shephard_Smith_Rep...   fire   316.81
# ...                                                   ...    ...      ...
# 294282  2016-12-07_0230_US_KCBS_CBS_Evening_News_With_...  study   935.07
# 294744           2016-11-02_0100_US_KOCE_The_PBS_Newshour  dress  1656.21
# 294753             2016-11-16_0030_US_KCAL_Inside_Edition  dress  1092.77
# 294769  2016-11-19_0230_US_KCBS_CBS_Evening_News_With_...  dress  1179.20
# 294791           2016-12-19_0130_US_KCBS_CBS_Weekend_News  dress   637.00
#
#                 end  duration       label_type mp4_error aac_error  \
# 361      377.459999      0.32  high-confidence  no-error  no-error
# 552      658.080000      0.34  high-confidence  no-error  no-error
# 610     1376.020000      0.42  high-confidence  no-error  no-error
# 656      740.590000      0.31  high-confidence  no-error  no-error
# 708      317.099999      0.29  high-confidence  no-error  no-error
# ...             ...       ...              ...       ...       ...
# 294282   935.540000      0.47  high-confidence  no-error  no-error
# 294744  1656.559999      0.35  high-confidence  no-error  no-error
# 294753  1093.150000      0.38  high-confidence  no-error  no-error
# 294769  1179.740000      0.54  high-confidence  no-error  no-error
# 294791   637.430000      0.43  high-confidence  no-error  no-error
#
#        aac2wav_error eafgz_error  ... seg_preceding_marker  \
# 361         no-error    no-error  ...                False
# 552         no-error    no-error  ...                False
# 610         no-error    no-error  ...                False
# 656         no-error    no-error  ...                False
# 708         no-error    no-error  ...                False
# ...              ...         ...  ...                  ...
# 294282      no-error    no-error  ...                False
# 294744      no-error    no-error  ...                False
# 294753      no-error    no-error  ...                False
# 294769      no-error    no-error  ...                False
# 294791      no-error    no-error  ...                False
#
#         seg_subsequent_marker        seg_merging   seg_index pos  rel1   rel2  \
# 361                     False  medium-confidence   1267038.0  NN  I-NP      O
# 552                     False  medium-confidence   2329196.0  NN  I-NP      O
# 610                     False  medium-confidence   2650735.0  NN  I-NP      O
# 656                     False  medium-confidence   2904383.0  NN  I-NP      O
# 708                     False  medium-confidence   3170657.0  NN  I-NP      O
# ...                       ...                ...         ...  ..   ...    ...
# 294282                   True  medium-confidence  20251518.0  NN  I-NP  I-PNP
# 294744                  False  medium-confidence  17955382.0  NN  I-NP  I-PNP
# 294753                  False  medium-confidence  18657740.0  VB  I-VP      O
# 294769                  False  medium-confidence  19008807.0  NN  I-NP      O
# 294791                  False  medium-confidence  21223392.0  NN  I-NP      O
#
#         lemma  m_score SylCnt
# 361      fire    0.863      2
# 552      fire    0.863      2
# 610      fire    0.863      2
# 656      fire    0.863      2
# 708      fire    0.863      2
# ...       ...      ...    ...
# 294282  study    1.000      2
# 294744  dress    1.000      1
# 294753  dress    1.000      1
# 294769  dress    1.000      1
# 294791  dress    1.000      1
#
# [3629 rows x 63 columns]

# %%
#preprocessed_df.to_csv("2016_all_words_no_audio_homographs_preprocessed.csv")

# %%
BASE = '/mnt/Restricted/Corpora/RedHen'
DATA_FOLDER = os.path.join(BASE, 'original')
DF_SOURCE_PATH = os.path.join(BASE, '2016_all_words_no_audio.pickle')
DF_HOMOGRAPH_PATH = os.path.join(BASE, 'homophone_analysis_scripts/2016_all_words_no_audio_homographs_preprocessed.csv')
celex_dict_file = "/mnt/shared/corpora/Celex/english/epw/epw.cd"

#STRETCHES_PATH = BASE + '/homophone_analysis_scripts'
STRETCHES_PATH = ''#'/mnt/shared/people/elnaz/homophones/10sec_stretch/'

NS = '<non-speech>'

# %%
df_hom = pd.read_csv(DF_HOMOGRAPH_PATH, index_col = "Unnamed: 0")

# %%
df_hom = df_hom.drop(columns=['seg_prev_word', 'seg_next_word', 'seg_end_of_sentence',
       'seg_start_of_sentence', 'seg_preceding_marker',
       'seg_subsequent_marker', 'seg_merging', 'seg_index', 'pos', 'rel1',
       'rel2', 'lemma'])

# %%
df_hom.columns
# Out:
# Index(['source_file', 'word', 'start', 'end', 'duration', 'label_type',
#        'mp4_error', 'aac_error', 'aac2wav_error', 'eafgz_error', 'seg_error',
#        'preceding_pause', 'subsequent_pause', 'word_frequency', 'prev_word',
#        'prev_word_frequency', 'next_word', 'next_word_frequency',
#        'length_in_letter', 'prev_word_string', 'next_word_string',
#        'prev_word_string_frequency', 'next_word_string_frequency',
#        'cond_pred_prev', 'cond_pred_next', 'disc', 'clx', 'disc_no_bound',
#        'clx_no_bound', 'gesture', 'HandMoving', 'PersonOnScreen',
#        'SpeakerOnScreen', 'HeadMoving/MovingVertically',
#        'ShoulderMoving/NotWithHead', 'HeadMoving/MovingHorizontally',
#        'ShoulderMoving/NoSlidingWindow', 'none',
#        'ShoulderMoving/SlidingWindow', 'is_gesture', 'video_snippet_size',
#        'gentle_prev_word', 'gentle_next_word', 'gentle_end_of_sentence',
#        'gentle_start_of_sentence', 'gentle_preceding_marker',
#        'gentle_subsequent_marker', 'gentle_merging', 'gentle_index', 'm_score',
#        'SylCnt'],
#       dtype='object')

# %%
df_hom
# Out:
#                                               source_file   word    start  \
# 0                  2016-01-01_0100_US_KNBC_Channel_4_News   fire    21.75
# 1                  2016-01-01_0100_US_KNBC_Channel_4_News   fire    46.35
# 2                  2016-01-01_0100_US_KNBC_Channel_4_News   fire    48.07
# 3                  2016-01-01_0100_US_KNBC_Channel_4_News   fire    68.99
# 4                  2016-01-01_0100_US_KNBC_Channel_4_News   fire    99.12
# ...                                                   ...    ...      ...
# 294813  2016-12-29_1400_US_CNN_CNN_Newsroom_With_Carol...  dress   182.11
# 294814  2016-12-29_1500_US_CNN_CNN_Newsroom_With_Carol...  dress  1350.66
# 294815  2016-12-31_0230_US_KCBS_CBS_Evening_News_With_...  dress  1550.44
# 294816                2016-12-31_1300_US_MSNBC_MSNBC_Live  dress   674.31
# 294817                2016-12-31_1300_US_MSNBC_MSNBC_Live  dress  1024.45
#
#                 end  duration       label_type mp4_error aac_error  \
# 0         22.110000      0.36  high-confidence  no-error  no-error
# 1         46.879999      0.53  high-confidence  no-error  no-error
# 2         48.290000      0.22  high-confidence  no-error  no-error
# 3         69.380000      0.39  high-confidence  no-error  no-error
# 4         99.370000      0.25  high-confidence  no-error  no-error
# ...             ...       ...              ...       ...       ...
# 294813   182.440000      0.33  high-confidence  no-error  no-error
# 294814  1351.050000      0.39  high-confidence  no-error  no-error
# 294815  1550.730000      0.29  high-confidence  no-error  no-error
# 294816   674.609999      0.30  high-confidence  no-error  no-error
# 294817  1024.739999      0.29  high-confidence  no-error  no-error
#
#        aac2wav_error eafgz_error  ... gentle_prev_word  gentle_next_word  \
# 0           no-error    no-error  ...             this             broke
# 1           no-error    no-error  ...              the               the
# 2           no-error    no-error  ...              the           started
# 3           no-error    no-error  ...            hotel            nearby
# 4           no-error    no-error  ...           caught                is
# ...              ...         ...  ...              ...               ...
# 294813      no-error    no-error  ...           subway                at
# 294814      no-error    no-error  ...        eccentric               and
# 294815      no-error    no-error  ...              NaN               NaN
# 294816      no-error    no-error  ...               at         rehearsal
# 294817      no-error    no-error  ...         princess               but
#
#         gentle_end_of_sentence  gentle_start_of_sentence  \
# 0                        False                     False
# 1                         True                     False
# 2                        False                     False
# 3                        False                     False
# 4                        False                     False
# ...                        ...                       ...
# 294813                   False                     False
# 294814                   False                     False
# 294815                     NaN                       NaN
# 294816                   False                     False
# 294817                    True                     False
#
#        gentle_preceding_marker  gentle_subsequent_marker   gentle_merging  \
# 0                        False                     False  high-confidence
# 1                        False                      True  high-confidence
# 2                        False                     False  high-confidence
# 3                        False                     False  high-confidence
# 4                        False                     False  high-confidence
# ...                        ...                       ...              ...
# 294813                   False                     False  high-confidence
# 294814                   False                     False  high-confidence
# 294815                     NaN                       NaN              NaN
# 294816                   False                     False  high-confidence
# 294817                   False                      True  high-confidence
#
#         gentle_index  m_score SylCnt
# 0               81.0    0.863      2
# 1              158.0    0.863      2
# 2              161.0    0.863      2
# 3              235.0    0.863      2
# 4              310.0    0.863      2
# ...              ...      ...    ...
# 294813    21452902.0    1.000      1
# 294814    21465305.0    1.000      1
# 294815           NaN    1.000      1
# 294816    21657916.0    1.000      1
# 294817    21658789.0    1.000      1
#
# [294818 rows x 51 columns]

# %%
#df_hom.to_csv("2016_all_words_no_audio_homographs_preprocessed.csv")
